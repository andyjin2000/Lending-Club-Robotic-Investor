# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import json
import requests

# %% [markdown]
# ## Get Current Data from Lending Club

# %%
api_key =open('apikey.txt','r').read()

headers = {'Authorization':api_key}
url='https://api.lendingclub.com/api/investor/v1/loans/listing'

r=requests.get(url, headers=headers)

# %%
type(r.json())
# Out:
# dict

# %%
r.json()
# Out:
# {'asOfDate': '2020-05-30T17:47:11.091-07:00',
#  'loans': [{'id': 169059471,
#    'memberId': 217757233,
#    'loanAmount': 6000.0,
#    'fundedAmount': 4525.0,
#    'term': 36,
#    'intRate': 14.71,
#    'expDefaultRate': 9.43,
#    'serviceFeeRate': 1.53,
#    'installment': 207.15,
#    'grade': 'B',
#    'subGrade': 'B3',
#    'empLength': 36,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 54000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2020-05-30T09:38:28.000-07:00',
#    'expD': '2020-06-29T14:00:00.000-07:00',
#    'listD': '2020-05-30T14:00:00.000-07:00',
#    'creditPullD': '2020-05-30T09:36:06.000-07:00',
#    'reviewStatusD': '2020-05-30T10:57:49.000-07:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '985xx',
#    'addrState': 'WA',
#    'investorCount': None,
#    'ilsExpD': '2020-05-30T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Operating engineer',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'bcOpenToBuy': 1476,
#    'percentBcGt75': 0.0,
#    'bcUtil': 73.2,
#    'dti': 15.89,
#    'delinq2Yrs': 1,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2015-08-29T17:00:00.000-07:00',
#    'ficoRangeLow': 665,
#    'ficoRangeHigh': 669,
#    'inqLast6Mths': 1,
#    'mthsSinceLastDelinq': 22,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 0,
#    'mthsSinceRecentRevolDelinq': 22,
#    'mthsSinceRecentBc': 31,
#    'mortAcc': 1,
#    'openAcc': 6,
#    'pubRec': 0,
#    'totalBalExMort': 19901,
#    'revolBal': 6161.0,
#    'revolUtil': 59.2,
#    'totalBcLimit': 5500,
#    'totalAcc': 9,
#    'totalIlHighCreditLimit': 22571,
#    'numRevAccts': 5,
#    'mthsSinceRecentBcDlq': 22,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': 22,
#    'numSats': 6,
#    'numTlOpPast12m': 1,
#    'moSinRcntTl': 7,
#    'totHiCredLim': 349636,
#    'totCurBal': 334319,
#    'avgCurBal': 55720,
#    'numBcTl': 3,
#    'numActvBcTl': 1,
#    'numBcSats': 1,
#    'pctTlNvrDlq': 88,
#    'numTl90gDpd24m': 1,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 3,
#    'moSinOldIlAcct': 57,
#    'numActvRevTl': 3,
#    'moSinOldRevTlOp': 49,
#    'moSinRcntRevTlOp': 30,
#    'totalRevHiLim': 10400,
#    'numRevTlBalGt0': 3,
#    'numOpRevTl': 3,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'mthsSinceRcntIl': 17,
#    'totalBalIl': 13740.0,
#    'iLUtil': 60.9,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'maxBalBc': 4024.0,
#    'allUtil': 60.4,
#    'inqFi': 2,
#    'totalCuTl': 0,
#    'inqLast12m': 2,
#    'mtgPayment': 1848.15,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 2,
#    'secAppOpenActIl': None},
#   {'id': 169056480,
#    'memberId': 217754227,
#    'loanAmount': 10000.0,
#    'fundedAmount': 6125.0,
#    'term': 36,
#    'intRate': 8.46,
#    'expDefaultRate': 4.67,
#    'serviceFeeRate': 1.28,
#    'installment': 315.5,
#    'grade': 'A',
#    'subGrade': 'A1',
#    'empLength': 120,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 85000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2020-05-30T09:22:07.000-07:00',
#    'expD': '2020-06-29T14:00:00.000-07:00',
#    'listD': '2020-05-30T14:00:00.000-07:00',
#    'creditPullD': '2020-05-30T09:21:21.000-07:00',
#    'reviewStatusD': '2020-05-30T09:55:12.000-07:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'home_improvement',
#    'addrZip': '432xx',
#    'addrState': 'OH',
#    'investorCount': None,
#    'ilsExpD': '2020-05-30T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'empTitle': 'SEnior Radiology Technologist',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 5,
#    'bcOpenToBuy': 26181,
#    'percentBcGt75': 0.0,
#    'bcUtil': 27.7,
#    'dti': 13.75,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2000-12-29T16:00:00.000-08:00',
#    'ficoRangeLow': 735,
#    'ficoRangeHigh': 739,
#    'inqLast6Mths': 1,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 0,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 8,
#    'mortAcc': 3,
#    'openAcc': 7,
#    'pubRec': 0,
#    'totalBalExMort': 44525,
#    'revolBal': 11794.0,
#    'revolUtil': 28.4,
#    'totalBcLimit': 36200,
#    'totalAcc': 23,
#    'totalIlHighCreditLimit': 37921,
#    'numRevAccts': 7,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 7,
#    'numTlOpPast12m': 4,
#    'moSinRcntTl': 3,
#    'totHiCredLim': 286621,
#    'totCurBal': 251100,
#    'avgCurBal': 35871,
#    'numBcTl': 4,
#    'numActvBcTl': 4,
#    'numBcSats': 4,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 13,
#    'moSinOldIlAcct': 233,
#    'numActvRevTl': 5,
#    'moSinOldRevTlOp': 165,
#    'moSinRcntRevTlOp': 8,
#    'totalRevHiLim': 41500,
#    'numRevTlBalGt0': 5,
#    'numOpRevTl': 5,
#    'totCollAmt': 183,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 1,
#    'openIl12m': 2,
#    'openIl24m': 2,
#    'mthsSinceRcntIl': 9,
#    'totalBalIl': 32731.0,
#    'iLUtil': None,
#    'openRv12m': 1,
#    'openRv24m': 2,
#    'maxBalBc': 4624.0,
#    'allUtil': 28.4,
#    'inqFi': 1,
#    'totalCuTl': 0,
#    'inqLast12m': 4,
#    'mtgPayment': 1365.67,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 1,
#    'secAppOpenActIl': None},
#   {'id': 169061495,
#    'memberId': 217759256,
#    'loanAmount': 40000.0,
#    'fundedAmount': 32500.0,
#    'term': 60,
#    'intRate': 14.02,
#    'expDefaultRate': 8.98,
#    'serviceFeeRate': 1.45,
#    'installment': 931.15,
#    'grade': 'B',
#    'subGrade': 'B2',
#    'empLength': 168,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 86000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2020-05-30T12:15:07.000-07:00',
#    'expD': '2020-06-29T14:00:00.000-07:00',
#    'listD': '2020-05-30T14:00:00.000-07:00',
#    'creditPullD': '2020-05-30T09:27:43.000-07:00',
#    'reviewStatusD': '2020-05-30T12:20:26.000-07:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '373xx',
#    'addrState': 'TN',
#    'investorCount': None,
#    'ilsExpD': '2020-05-30T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Long Haul Truck Driver',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'bcOpenToBuy': 10645,
#    'percentBcGt75': 33.3,
#    'bcUtil': 61.1,
#    'dti': 29.96,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2007-02-27T16:00:00.000-08:00',
#    'ficoRangeLow': 730,
#    'ficoRangeHigh': 734,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 3,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 38,
#    'mortAcc': 2,
#    'openAcc': 13,
#    'pubRec': 0,
#    'totalBalExMort': 129002,
#    'revolBal': 26679.0,
#    'revolUtil': 47.1,
#    'totalBcLimit': 27400,
#    'totalAcc': 30,
#    'totalIlHighCreditLimit': 126866,
#    'numRevAccts': 11,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 13,
#    'numTlOpPast12m': 0,
#    'moSinRcntTl': 15,
#    'totHiCredLim': 468961,
#    'totCurBal': 383304,
#    'avgCurBal': 29485,
#    'numBcTl': 4,
#    'numActvBcTl': 3,
#    'numBcSats': 3,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 17,
#    'moSinOldIlAcct': 159,
#    'numActvRevTl': 5,
#    'moSinOldRevTlOp': 96,
#    'moSinRcntRevTlOp': 15,
#    'totalRevHiLim': 56600,
#    'numRevTlBalGt0': 5,
#    'numOpRevTl': 7,
#    'totCollAmt': 0,
#    'applicationType': 'JOINT',
#    'annualIncJoint': 131676.0,
#    'dtiJoint': 26.28,
#    'isIncVJoint': 'SOURCE_VERIFIED',
#    'openAcc6m': 0,
#    'openIl12m': 0,
#    'openIl24m': 2,
#    'mthsSinceRcntIl': 18,
#    'totalBalIl': 102323.0,
#    'iLUtil': 56.9,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'maxBalBc': 8338.0,
#    'allUtil': 51.1,
#    'inqFi': 0,
#    'totalCuTl': 7,
#    'inqLast12m': 3,
#    'mtgPayment': 1935.64,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'openActIl': 4,
#    'secAppOpenActIl': None}]}

# %%
data = r.json()
myData =data['loans']

# %% [markdown]
# ## with open() as

# %%
with open('current_list.txt', 'w') as outfile:
    json.dump(myData, outfile)

# %%
df_current=pd.read_json('current_list.txt')

# %%
# why we only get few loans through api, but there are much more listed on the lending club website?  -- Might because API only 
# gives you the data from the latest update.

df_current.tail()
# Out:
#           id   memberId  loanAmount  fundedAmount  term  intRate  \
# 0  169059471  217757233        6000          4525    36    14.71
# 1  169056480  217754227       10000          6125    36     8.46
# 2  169061495  217759256       40000         32500    60    14.02
#
#    expDefaultRate  serviceFeeRate  installment grade  ... secAppOpenAcc  \
# 0            9.43            1.53       207.15     B  ...           NaN
# 1            4.67            1.28       315.50     A  ...           NaN
# 2            8.98            1.45       931.15     B  ...           NaN
#
#    secAppRevolUtil secAppNumRevAccts  secAppChargeoffWithin12Mths  \
# 0              NaN               NaN                          NaN
# 1              NaN               NaN                          NaN
# 2              NaN               NaN                          NaN
#
#   secAppCollections12MthsExMed secAppMthsSinceLastMajorDerog revolBalJoint  \
# 0                          NaN                           NaN           NaN
# 1                          NaN                           NaN           NaN
# 2                          NaN                           NaN           NaN
#
#   disbursementMethod openActIl secAppOpenActIl
# 0               CASH         2             NaN
# 1               CASH         1             NaN
# 2         DIRECT_PAY         4             NaN
#
# [3 rows x 119 columns]

# %%
# A better way to read a json file (can read json to data frame with more complex structure)

df_current = pd.io.json.json_normalize(myData)
# Out:
# /Users/andyjin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_current.tail()
# Out:
#           id   memberId  loanAmount  fundedAmount  term  intRate  \
# 0  169059471  217757233      6000.0        4525.0    36    14.71
# 1  169056480  217754227     10000.0        6125.0    36     8.46
# 2  169061495  217759256     40000.0       32500.0    60    14.02
#
#    expDefaultRate  serviceFeeRate  installment grade  ... secAppOpenAcc  \
# 0            9.43            1.53       207.15     B  ...          None
# 1            4.67            1.28       315.50     A  ...          None
# 2            8.98            1.45       931.15     B  ...          None
#
#    secAppRevolUtil secAppNumRevAccts  secAppChargeoffWithin12Mths  \
# 0             None              None                         None
# 1             None              None                         None
# 2             None              None                         None
#
#   secAppCollections12MthsExMed secAppMthsSinceLastMajorDerog revolBalJoint  \
# 0                         None                          None          None
# 1                         None                          None          None
# 2                         None                          None          None
#
#   disbursementMethod openActIl secAppOpenActIl
# 0               CASH         2            None
# 1               CASH         1            None
# 2         DIRECT_PAY         4            None
#
# [3 rows x 119 columns]

# %% [markdown]
# ## Historical Data

# %%
df_2017 = pd.read_csv('LoanStats_securev1_2017Q1.csv', skiprows=1)
# Out:
# /Users/andyjin/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (118) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_2017.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term'],
#       dtype='object', length=150)

# %%
df_2017.shape
# Out:
# (96678, 150)

# %%
print('----------current-----------------')
for col in df_current.columns.values:
    print(col)
print('----------current-----------------')
# Out:
# ----------current-----------------
# id
# memberId
# loanAmount
# fundedAmount
# term
# intRate
# expDefaultRate
# serviceFeeRate
# installment
# grade
# subGrade
# empLength
# homeOwnership
# annualInc
# isIncV
# acceptD
# expD
# listD
# creditPullD
# reviewStatusD
# reviewStatus
# desc
# purpose
# addrZip
# addrState
# investorCount
# ilsExpD
# initialListStatus
# empTitle
# accNowDelinq
# accOpenPast24Mths
# bcOpenToBuy
# percentBcGt75
# bcUtil
# dti
# delinq2Yrs
# delinqAmnt
# earliestCrLine
# ficoRangeLow
# ficoRangeHigh
# inqLast6Mths
# mthsSinceLastDelinq
# mthsSinceLastRecord
# mthsSinceRecentInq
# mthsSinceRecentRevolDelinq
# mthsSinceRecentBc
# mortAcc
# openAcc
# pubRec
# totalBalExMort
# revolBal
# revolUtil
# totalBcLimit
# totalAcc
# totalIlHighCreditLimit
# numRevAccts
# mthsSinceRecentBcDlq
# pubRecBankruptcies
# numAcctsEver120Ppd
# chargeoffWithin12Mths
# collections12MthsExMed
# taxLiens
# mthsSinceLastMajorDerog
# numSats
# numTlOpPast12m
# moSinRcntTl
# totHiCredLim
# totCurBal
# avgCurBal
# numBcTl
# numActvBcTl
# numBcSats
# pctTlNvrDlq
# numTl90gDpd24m
# numTl30dpd
# numTl120dpd2m
# numIlTl
# moSinOldIlAcct
# numActvRevTl
# moSinOldRevTlOp
# moSinRcntRevTlOp
# totalRevHiLim
# numRevTlBalGt0
# numOpRevTl
# totCollAmt
# applicationType
# annualIncJoint
# dtiJoint
# isIncVJoint
# openAcc6m
# openIl12m
# openIl24m
# mthsSinceRcntIl
# totalBalIl
# iLUtil
# openRv12m
# openRv24m
# maxBalBc
# allUtil
# inqFi
# totalCuTl
# inqLast12m
# mtgPayment
# housingPayment
# secAppFicoRangeLow
# secAppFicoRangeHigh
# secAppEarliestCrLine
# secAppInqLast6Mths
# secAppMortAcc
# secAppOpenAcc
# secAppRevolUtil
# secAppNumRevAccts
# secAppChargeoffWithin12Mths
# secAppCollections12MthsExMed
# secAppMthsSinceLastMajorDerog
# revolBalJoint
# disbursementMethod
# openActIl
# secAppOpenActIl
# ----------current-----------------

# %%
print('----------current-----------------')
for col in df_2017.columns.values:
    print(col)
print('----------current-----------------')
# Out:
# ----------current-----------------
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
# revol_bal_joint
# sec_app_fico_range_low
# sec_app_fico_range_high
# sec_app_earliest_cr_line
# sec_app_inq_last_6mths
# sec_app_mort_acc
# sec_app_open_acc
# sec_app_revol_util
# sec_app_open_act_il
# sec_app_num_rev_accts
# sec_app_chargeoff_within_12_mths
# sec_app_collections_12_mths_ex_med
# sec_app_mths_since_last_major_derog
# hardship_flag
# hardship_type
# hardship_reason
# hardship_status
# deferral_term
# hardship_amount
# hardship_start_date
# hardship_end_date
# payment_plan_start_date
# hardship_length
# hardship_dpd
# hardship_loan_status
# orig_projected_additional_accrued_interest
# hardship_payoff_balance_amount
# hardship_last_payment_amount
# debt_settlement_flag
# debt_settlement_flag_date
# settlement_status
# settlement_date
# settlement_amount
# settlement_percentage
# settlement_term
# ----------current-----------------

# %% [markdown]
# ## Format conversion of feature names

# %%
current_feature = list(df_current.columns.values)

# %%
for i in range (len(current_feature)):
    current_feature[i] = str.lower(str(current_feature[i]))

# %%
current_feature[:5]
# Out:
# ['id', 'memberid', 'loanamount', 'fundedamount', 'term']

# %%
his_feature = list(df_2017.columns.values)

# %%
for i in range (len(his_feature)):
    his_feature[i] = str(his_feature[i]).replace('_','')

# %%
his_feature[:5]
# Out:
# ['id', 'memberid', 'loanamnt', 'fundedamnt', 'fundedamntinv']

# %%
common_feature = set(his_feature)&(set(current_feature))
print(len(common_feature))
print(common_feature)
# Out:
# 100
# {'secappcollections12mthsexmed', 'openil12m', 'mthssincelastmajorderog', 'secappficorangelow', 'homeownership', 'numtloppast12m', 'totcurbal', 'numsats', 'revolbaljoint', 'revolutil', 'pubrec', 'openrv12m', 'chargeoffwithin12mths', 'numrevaccts', 'numtl90gdpd24m', 'memberid', 'openrv24m', 'openil24m', 'totalrevhilim', 'allutil', 'mthssincelastrecord', 'mthssincerecentbcdlq', 'mosinrcnttl', 'numtl120dpd2m', 'taxliens', 'secappopenactil', 'numiltl', 'secappficorangehigh', 'mosinoldilacct', 'ilutil', 'mthssincelastdelinq', 'numoprevtl', 'inqfi', 'pcttlnvrdlq', 'mthssincercntil', 'totalilhighcreditlimit', 'applicationtype', 'secappinqlast6mths', 'mortacc', 'annualincjoint', 'revolbal', 'secapprevolutil', 'accnowdelinq', 'id', 'avgcurbal', 'mosinrcntrevtlop', 'initialliststatus', 'bcopentobuy', 'secappmthssincelastmajorderog', 'delinqamnt', 'maxbalbc', 'totcollamt', 'openactil', 'mthssincerecentinq', 'totalacc', 'openacc6m', 'intrate', 'inqlast6mths', 'percentbcgt75', 'delinq2yrs', 'pubrecbankruptcies', 'totalbalil', 'numbctl', 'grade', 'bcutil', 'ficorangelow', 'desc', 'mosinoldrevtlop', 'numrevtlbalgt0', 'secappearliestcrline', 'term', 'numtl30dpd', 'installment', 'emptitle', 'emplength', 'totalbalexmort', 'dti', 'numactvrevtl', 'ficorangehigh', 'numactvbctl', 'subgrade', 'totalbclimit', 'earliestcrline', 'inqlast12m', 'purpose', 'accopenpast24mths', 'dtijoint', 'numbcsats', 'tothicredlim', 'annualinc', 'secappmortacc', 'mthssincerecentrevoldelinq', 'totalcutl', 'addrstate', 'collections12mthsexmed', 'secappchargeoffwithin12mths', 'secappnumrevaccts', 'openacc', 'mthssincerecentbc', 'secappopenacc'}

# %%
his_unique=set(his_feature)-set(current_feature)
current_unique=set(current_feature)-set(his_feature)
print(len(current_unique), current_unique)
print(len(his_unique), his_unique)
# Out:
# 19 {'expd', 'isincvjoint', 'acceptd', 'servicefeerate', 'expdefaultrate', 'reviewstatusd', 'investorcount', 'housingpayment', 'mtgpayment', 'reviewstatus', 'listd', 'numacctsever120ppd', 'addrzip', 'fundedamount', 'isincv', 'creditpulld', 'ilsexpd', 'loanamount', 'disbursementmethod'}
# 50 {'paymentplanstartdate', 'deferralterm', 'totalreclatefee', 'numacctsever120pd', 'recoveries', 'totalrecprncp', 'loanamnt', 'policycode', 'settlementpercentage', 'hardshipstartdate', 'debtsettlementflag', 'settlementamount', 'settlementterm', 'loanstatus', 'lastpymntamnt', 'totalrecint', 'lastficorangelow', 'verificationstatusjoint', 'url', 'origprojectedadditionalaccruedinterest', 'outprncpinv', 'fundedamntinv', 'hardshippayoffbalanceamount', 'lastcreditpulld', 'hardshipflag', 'hardshiplength', 'settlementstatus', 'fundedamnt', 'lastpymntd', 'hardshiplastpaymentamount', 'totalpymnt', 'totalpymntinv', 'hardshipreason', 'collectionrecoveryfee', 'debtsettlementflagdate', 'hardshipdpd', 'pymntplan', 'lastficorangehigh', 'settlementdate', 'verificationstatus', 'outprncp', 'zipcode', 'hardshiploanstatus', 'hardshipstatus', 'issued', 'hardshipamount', 'nextpymntd', 'hardshipenddate', 'hardshiptype', 'title'}

# %%
feature_dic={}
feature_dic['common_feature']=common_feature
feature_dic['his_unique']=his_unique
feature_dic['current_unique']=current_unique

# %%
feature_dic['current_unique']
# Out:
# {'acceptd',
#  'addrzip',
#  'creditpulld',
#  'disbursementmethod',
#  'expd',
#  'expdefaultrate',
#  'fundedamount',
#  'housingpayment',
#  'ilsexpd',
#  'investorcount',
#  'isincv',
#  'isincvjoint',
#  'listd',
#  'loanamount',
#  'mtgpayment',
#  'numacctsever120ppd',
#  'reviewstatus',
#  'reviewstatusd',
#  'servicefeerate'}

# %%
feature_dic['his_unique']
# Out:
# {'collectionrecoveryfee',
#  'debtsettlementflag',
#  'debtsettlementflagdate',
#  'deferralterm',
#  'fundedamnt',
#  'fundedamntinv',
#  'hardshipamount',
#  'hardshipdpd',
#  'hardshipenddate',
#  'hardshipflag',
#  'hardshiplastpaymentamount',
#  'hardshiplength',
#  'hardshiploanstatus',
#  'hardshippayoffbalanceamount',
#  'hardshipreason',
#  'hardshipstartdate',
#  'hardshipstatus',
#  'hardshiptype',
#  'issued',
#  'lastcreditpulld',
#  'lastficorangehigh',
#  'lastficorangelow',
#  'lastpymntamnt',
#  'lastpymntd',
#  'loanamnt',
#  'loanstatus',
#  'nextpymntd',
#  'numacctsever120pd',
#  'origprojectedadditionalaccruedinterest',
#  'outprncp',
#  'outprncpinv',
#  'paymentplanstartdate',
#  'policycode',
#  'pymntplan',
#  'recoveries',
#  'settlementamount',
#  'settlementdate',
#  'settlementpercentage',
#  'settlementstatus',
#  'settlementterm',
#  'title',
#  'totalpymnt',
#  'totalpymntinv',
#  'totalrecint',
#  'totalreclatefee',
#  'totalrecprncp',
#  'url',
#  'verificationstatus',
#  'verificationstatusjoint',
#  'zipcode'}

# %%
feature_dic['common_feature']
# Out:
# {'accnowdelinq',
#  'accopenpast24mths',
#  'addrstate',
#  'allutil',
#  'annualinc',
#  'annualincjoint',
#  'applicationtype',
#  'avgcurbal',
#  'bcopentobuy',
#  'bcutil',
#  'chargeoffwithin12mths',
#  'collections12mthsexmed',
#  'delinq2yrs',
#  'delinqamnt',
#  'desc',
#  'dti',
#  'dtijoint',
#  'earliestcrline',
#  'emplength',
#  'emptitle',
#  'ficorangehigh',
#  'ficorangelow',
#  'grade',
#  'homeownership',
#  'id',
#  'ilutil',
#  'initialliststatus',
#  'inqfi',
#  'inqlast12m',
#  'inqlast6mths',
#  'installment',
#  'intrate',
#  'maxbalbc',
#  'memberid',
#  'mortacc',
#  'mosinoldilacct',
#  'mosinoldrevtlop',
#  'mosinrcntrevtlop',
#  'mosinrcnttl',
#  'mthssincelastdelinq',
#  'mthssincelastmajorderog',
#  'mthssincelastrecord',
#  'mthssincercntil',
#  'mthssincerecentbc',
#  'mthssincerecentbcdlq',
#  'mthssincerecentinq',
#  'mthssincerecentrevoldelinq',
#  'numactvbctl',
#  'numactvrevtl',
#  'numbcsats',
#  'numbctl',
#  'numiltl',
#  'numoprevtl',
#  'numrevaccts',
#  'numrevtlbalgt0',
#  'numsats',
#  'numtl120dpd2m',
#  'numtl30dpd',
#  'numtl90gdpd24m',
#  'numtloppast12m',
#  'openacc',
#  'openacc6m',
#  'openactil',
#  'openil12m',
#  'openil24m',
#  'openrv12m',
#  'openrv24m',
#  'pcttlnvrdlq',
#  'percentbcgt75',
#  'pubrec',
#  'pubrecbankruptcies',
#  'purpose',
#  'revolbal',
#  'revolbaljoint',
#  'revolutil',
#  'secappchargeoffwithin12mths',
#  'secappcollections12mthsexmed',
#  'secappearliestcrline',
#  'secappficorangehigh',
#  'secappficorangelow',
#  'secappinqlast6mths',
#  'secappmortacc',
#  'secappmthssincelastmajorderog',
#  'secappnumrevaccts',
#  'secappopenacc',
#  'secappopenactil',
#  'secapprevolutil',
#  'subgrade',
#  'taxliens',
#  'term',
#  'totalacc',
#  'totalbalexmort',
#  'totalbalil',
#  'totalbclimit',
#  'totalcutl',
#  'totalilhighcreditlimit',
#  'totalrevhilim',
#  'totcollamt',
#  'totcurbal',
#  'tothicredlim'}

# %%
# add common features that have different names for current and historical data. Use the form in the historical data)

common_feature=common_feature.union({'zipcode', 
 'fundedamnt',
 'verificationstatus',
 'verificationstatusjoint',
 'loanamnt',
 'numacctsever120pd'})
len(common_feature)
# Out:
# 106

# %% [markdown]
# ### Convert column names in the data frame and save dataframe with common features and issued, loanstatus

# %%
for col in df_2017.columns.values:
    df_2017.rename(columns={str(col):str(col).replace('_','')}, inplace=True)

# %%
df_2017_1=df_2017[list(common_feature)+['issued', 'loanstatus']]

# %%
df_2017_1.shape
# Out:
# (96678, 108)

# %%
df_2017_1.to_csv('loan_2017.csv',index=False)

# %%
df=pd.read_csv('loan_2017.csv')
# Out:
# /Users/andyjin/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        openactil  secappcollections12mthsexmed  mthssincerecentinq  openil12m  \
# 0              3                           NaN                 8.0          1
# 1              1                           NaN                 1.0          0
# 2              8                           NaN                10.0          2
# 3              4                           NaN                 0.0          0
# 4              2                           NaN                 NaN          1
# ...          ...                           ...                 ...        ...
# 96673         15                           NaN                 0.0          1
# 96674          1                           NaN                 4.0          0
# 96675          1                           NaN                 NaN          0
# 96676          1                           NaN                 NaN          1
# 96677          1                           NaN                17.0          0
#
#        mthssincelastmajorderog  totalacc  openacc6m  secappficorangelow  \
# 0                          NaN        25          0                 NaN
# 1                          NaN        23          0                 NaN
# 2                          NaN        35          0                 NaN
# 3                          NaN        24          1                 NaN
# 4                          NaN        25          1                 NaN
# ...                        ...       ...        ...                 ...
# 96673                     34.0        38          1                 NaN
# 96674                      NaN        15          4                 NaN
# 96675                      NaN        15          0                 NaN
# 96676                     25.0        17          2                 NaN
# 96677                     68.0        18          0                 NaN
#
#       intrate  loanamnt  ... bcopentobuy  openacc  \
# 0      12.74%     16000  ...      9837.0       18
# 1      11.44%     13000  ...     15081.0       11
# 2      11.39%     15400  ...     14163.0       20
# 3       6.99%      3025  ...     14205.0       13
# 4      11.39%      9000  ...     25905.0       13
# ...       ...       ...  ...         ...      ...
# 96673  21.49%     30000  ...         0.0       21
# 96674  12.74%     15000  ...     40900.0       13
# 96675   8.24%     10000  ...      5485.0        8
# 96676  15.99%      6325  ...      9211.0       12
# 96677  28.69%     15625  ...      6690.0       13
#
#        secappmthssincelastmajorderog  delinqamnt  maxbalbc  mthssincerecentbc  \
# 0                                NaN           0      9429               60.0
# 1                                NaN           0      8419               76.0
# 2                                NaN           0      4600               16.0
# 3                                NaN           0     11947                4.0
# 4                                NaN           0      3837                6.0
# ...                              ...         ...       ...                ...
# 96673                            NaN           0      7038              112.0
# 96674                            NaN           0      5515                3.0
# 96675                            NaN           0      4280               25.0
# 96676                            NaN           0       989                6.0
# 96677                            NaN           0      6478               16.0
#
#        secappopenacc  totcollamt  issued   loanstatus
# 0                NaN           0  Mar-17      Current
# 1                NaN           0  Mar-17      Current
# 2                NaN           0  Mar-17   Fully Paid
# 3                NaN           0  Mar-17      Current
# 4                NaN           0  Mar-17   Fully Paid
# ...              ...         ...     ...          ...
# 96673            NaN           0  Jan-17   Fully Paid
# 96674            NaN           0  Jan-17   Fully Paid
# 96675            NaN           0  Jan-17   Fully Paid
# 96676            NaN        1465  Jan-17   Fully Paid
# 96677            NaN           0  Jan-17  Charged Off
#
# [96678 rows x 108 columns]

# %% [markdown]
# ## current feature listd, acceptd

# %%
df_current.columns
# Out:
# Index(['id', 'memberId', 'loanAmount', 'fundedAmount', 'term', 'intRate',
#        'expDefaultRate', 'serviceFeeRate', 'installment', 'grade',
#        ...
#        'secAppOpenAcc', 'secAppRevolUtil', 'secAppNumRevAccts',
#        'secAppChargeoffWithin12Mths', 'secAppCollections12MthsExMed',
#        'secAppMthsSinceLastMajorDerog', 'revolBalJoint', 'disbursementMethod',
#        'openActIl', 'secAppOpenActIl'],
#       dtype='object', length=119)

# %%
df_current[['listD','acceptD']][:10]
# Out:
#                            listD                        acceptD
# 0  2020-05-30T14:00:00.000-07:00  2020-05-30T09:38:28.000-07:00
# 1  2020-05-30T14:00:00.000-07:00  2020-05-30T09:22:07.000-07:00
# 2  2020-05-30T14:00:00.000-07:00  2020-05-30T12:15:07.000-07:00
